# %% [markdown]
# Make sure that the parent directory is on our python path

# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
from Data.data_processing import load_data, split_data, to_univariate, to_daily, missing_values, data_normalization, to_supervised, prepare_train, plot_incidents
from models import generate_configs, grid_search

# %%
multisteps = 5 # number of days to forecast (we will forecast the next 5 days)
cv_splits = 3  # time series cross validator

# define ranges to generate diferent configurations to evaluate the models
timesteps = [5, 7]
epochs = [10, 20]
batch_size = [5, 7]
filters = [16]
kernel_size = [5]
pool_size = [2]

# %%
path = '../Data/Traffic_Incidents_Braga.csv'

df_raw = load_data(path)        # load dataset
df_uni = to_daily(df_raw)       # convert data to univariate and group incidents by day
df_uni = missing_values(df_uni) # deal with missing values

scaler = data_normalization(df_uni) # scaling data to [-1, 1]

# %%
configs = generate_configs(timesteps, epochs, batch_size, filters, kernel_size, pool_size) # generate a list with all the possible configurations
# Out:
# Generated 8 different configurations

# %%
features = 1 # univariate

scores = grid_search(df_uni, configs, features) # sort configuration by performance
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Epoch 1/10
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3553 - mae: 0.3298 - rmse: 0.3544 - val_loss: 0.2692 - val_mae: 0.2337 - val_rmse: 0.2977
# Epoch 2/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1570 - mae: 0.1330 - rmse: 0.1572 - val_loss: 0.2731 - val_mae: 0.2427 - val_rmse: 0.3011
# Epoch 3/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1528 - mae: 0.1297 - rmse: 0.1529 - val_loss: 0.2674 - val_mae: 0.2398 - val_rmse: 0.2918
# Epoch 4/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1487 - mae: 0.1266 - rmse: 0.1489 - val_loss: 0.2632 - val_mae: 0.2379 - val_rmse: 0.2837
# Epoch 5/10
# 39/39 [==============================] - 0s 2ms/step - loss: 0.1453 - mae: 0.1243 - rmse: 0.1455 - val_loss: 0.2574 - val_mae: 0.2331 - val_rmse: 0.2747
# ...

# %%
from models import build_cnn, compile_and_fit, forecast_single, forecast_multi

best_config = [7, 20, 7, 16, 5, 2]
model = build_cnn(best_config, features)
compile_and_fit(df_uni, model, best_config)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')
# Epoch 1/20
# 28/28 [==============================] - 0s 9ms/step - loss: 0.4603 - mae: 0.4363 - rmse: 0.4546 - val_loss: 0.2411 - val_mae: 0.2020 - val_rmse: 0.2411
# Epoch 2/20
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1561 - mae: 0.1300 - rmse: 0.1564 - val_loss: 0.2475 - val_mae: 0.2228 - val_rmse: 0.2475
# Epoch 3/20
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1467 - mae: 0.1237 - rmse: 0.1472 - val_loss: 0.2476 - val_mae: 0.2259 - val_rmse: 0.2476
# Epoch 4/20
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1439 - mae: 0.1224 - rmse: 0.1444 - val_loss: 0.2444 - val_mae: 0.2220 - val_rmse: 0.2444
# Epoch 5/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1426 - mae: 0.1216 - rmse: 0.1431 - val_loss: 0.2419 - val_mae: 0.2185 - val_rmse: 0.2419
# ...

# %%
forecast_single(model, df_uni, 7, scaler)
# Out:
# 229.60567

# %%
multisteps = 5

forecast_multi(model, df_uni, 7, multisteps, scaler)
# Out:
# [229.60567, 284.47437, 279.8555, 214.53072, 245.85753]
